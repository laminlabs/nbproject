# %% [markdown]
# # My task X

# %%
# %%time
from nbproject import header

header()

# %%
import pandas as pd
import pydantic

# %%
df = pd.DataFrame({"a": [1, 2, 3], "b": [2, 3, 4]})

# %%
df

# %%
df.mean()
